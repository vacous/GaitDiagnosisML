# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.svm import SVC, NuSVC
from sklearn.mixture import GaussianMixture
from sklearn import linear_model, ensemble
from scipy.signal import find_peaks_cwt
from FeatureAnalysis import RescalePCA, HistFeature
from DataProcessing import ToPandasData, DataCombiner, DataAugmentor
from DataVisulization import VisCompareTwoPCA
import random

# %%
DATA_COMBINER = DataCombiner()
# convert all trial data and to be ready to pass in to the PCA 
gait_types = ['normal', # normal
             'fd',# foot drop
             'hem', #Hemiplegic Gait
             'injured']
# store all original data into a dictionary 
max_trials = 5
print('All Trials: ')
for each_type in gait_types:
    for each_trial_num in range(1,max_trials + 1):
        cur_trial_name = each_type + '_0' + str(each_trial_num)
        DATA_COMBINER.addNewTrial(ToPandasData('../Data_Collection/' + cur_trial_name + '.txt'), each_type)
    print(each_type + ': ' + str(list(range(1,max_trials + 1))))
# Out:
# All Trials:
# normal: [1, 2, 3, 4, 5]
# fd: [1, 2, 3, 4, 5]
# hem: [1, 2, 3, 4, 5]
# injured: [1, 2, 3, 4, 5]

# %%
All_combined_data = DATA_COMBINER.combineAllData()
DATA_AUG = DataAugmentor(All_combined_data)
All_aug_data = DATA_AUG.subSampleAll(out_length=5000, num_draw=150, std_percentile=5)

# %%
PCA_all = RescalePCA()
PCA_all.processRescalePCA(All_combined_data, reduced_dim=3)
print(PCA_all)
# Out:
# PCA Info:
# [ 0.39353648  0.32900827  0.1798072 ]
# Rescale Info:
# Voltage_02: (1.0, 0.0)
# Acc_y: (36.189999999999998, -57.609999999999999)
# Voltage_01: (1.0, 0.0)
# Acc_x: (16.890000000000001, -42.229999999999997)
# Gyro_z: (4.1799999999999997, -4.2800000000000002)
# Gyro_x: (4.2800000000000002, -4.2800000000000002)
# Gyro_y: (4.2699999999999996, -4.2800000000000002)
# Acc_z: (78.469999999999999, -22.219999999999999)
# Component Range:
# [-0.52 -0.52 -0.55]
# [ 0.83  0.76  0.59]
# Feature Order: {'Voltage_02': 1, 'Acc_y': 3, 'Voltage_01': 0, 'Acc_x': 2, 'Gyro_z': 7, 'Gyro_x': 5, 'Gyro_y': 6, 'Acc_z': 4}

# %%
num_hist_bins = 10
# combine all the trials data into HistFeatures and combined into a matrix for modeling training 
# buffer the feature matrix and label array
num_train_samples = sum([len(All_aug_data[each_type]) for each_type in All_aug_data])
train_matrix = np.zeros((num_train_samples, 3 * num_hist_bins))
train_labels = np.zeros(num_train_samples)
# process each sample for the hist features
idx = 0
for each_type in All_aug_data:
    cur_samples = All_aug_data[each_type]
    cur_type_idx = gait_types.index(each_type)
    for sample in cur_samples:
        cur_pca = PCA_all.applyRescalePCA(sample)
        train_matrix[idx,:] = HistFeature(cur_pca, PCA_all.component_range, num_hist_bins)
        train_labels[idx] = cur_type_idx
        idx += 1

# %%
print(sum(train_matrix[5,:]), train_labels.shape)
# Out:
# 3.0 (600,)

# %%
# test case for testing models
test_case_name = 'ran_03'
test_case = ToPandasData('../Data_Collection/' + test_case_name + '.txt')
test_in = PCA_all.applyRescalePCA(test_case)
test_fea = HistFeature(test_in, PCA_all.component_range, num_hist_bins)
# test case 2
test_case_2_name = 'hem_01'
test_case_2 = ToPandasData('../Data_Collection/' + test_case_2_name + '.txt')
test_in_2 = PCA_all.applyRescalePCA(test_case_2)
test_fea_2 = HistFeature(test_in_2, PCA_all.component_range, num_hist_bins)

# %%
VisCompareTwoPCA(test_in, test_in_2, PCA_all, test_case_name, test_case_2_name)

# %%
test_svc = NuSVC(probability=True)
test_svc.fit(train_matrix, train_labels)
print('SVM')
print(test_svc.predict_proba([test_fea]))
print(test_svc.predict_proba([test_fea_2]))
# Out:
# SVM
# [[ 0.89864115  0.02355741  0.04137983  0.03642162]]
# [[ 0.00264468  0.001635    0.99437709  0.00134323]]

# %%
# train the GMM model 
test_gau = GaussianMixture(n_components=4, init_params='kmeans')
test_gau.fit(train_matrix)
# the model on the training data
# for idx in range(len(actual_label)):
#     print(gait_names[int(actual_label[idx])] + ': ' + str(pred_result[idx]*100)) 
# print('--------------------------')
print('GMM')
print(test_gau.predict_proba([test_fea]))

# Test if logistc regrisson works 
test_log = linear_model.LogisticRegression()
test_log.fit(train_matrix, train_labels)
print('Log')
print(test_log.predict_proba([test_fea]))
print(test_log.predict_proba([test_fea_2]))

# Support vector machine  
test_svc = NuSVC(probability=True)
test_svc.fit(train_matrix, train_labels)
print('SVM')
print(test_svc.predict_proba([test_fea]))
print(test_svc.predict_proba([test_fea_2]))

# Adaboost
test_ada = ensemble.AdaBoostClassifier()
test_ada.fit(train_matrix, train_labels)
print('Ada')
print(test_ada.predict_proba([test_fea]))
print(test_ada.predict_proba([test_fea_2]))
# Out:
# GMM
# [[ 0.  0.  1.  0.]]
# Log
# [[ 0.67496533  0.06001064  0.12879238  0.13623165]]
# [[ 0.04450837  0.39960261  0.53507504  0.02081397]]
# SVM
# [[ 0.89704083  0.02475175  0.04142587  0.03678156]]
# [[ 0.00266322  0.00207146  0.99390616  0.00135916]]
# Ada
# [[  9.99194452e-01   4.02773937e-04   4.02773937e-04   6.34401272e-12]]
# [[  6.77263257e-12   5.00000000e-01   5.00000000e-01   9.93085011e-12]]

# %%
def FFTFeature(pca_data, in_time):
    for idx in range(pca_data.shape[1]):
        cur_data = pca_data[:,idx]
        # fft to find the major frequency for the current data 
        sample_freq = np.mean(1/(np.diff(in_time)))
        sample_period = 1/sample_freq
        sig_len = len(cur_data)
        fft_result = np.fft.fft(cur_data)
        sig_fft = np.abs(fft_result/sig_len)
        
        # plot fft freq result 
        hf_len = int(sig_len/2) 
        fft_y = sig_fft[1:hf_len + 1]
        fft_y[1:-1] = 2 * fft_y[1:-1]
        freq_x = sample_freq * range(0,hf_len)/sig_len
        
        plt.figure(figsize= (15, 5))         
        idx_xs = find_peaks_cwt(fft_y[freq_x < 10], np.arange(0.1, 1, 0.2), noise_perc = 99.99)
        plt.subplot(121)
        plt.plot(freq_x[idx_xs], fft_y[idx_xs], 'ro')
        plt.plot(freq_x, fft_y)
        plt.subplot(122)
        plt.hist(fft_y[idx_xs], bins = 10, ec = 'black')

# %%
FFTFeature(test_in_2, test_case_2['Time'])
